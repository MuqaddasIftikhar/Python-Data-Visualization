# %% [markdown]
# # Bar Plot

# %% [markdown]
# # Import Libraries:

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Load dataset

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load dataset
flower=sns.load_dataset("iris")
flower
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flower.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
flower.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
flower.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load dataset
flower=sns.load_dataset("iris")
flower
# Draw a bar plot 
sns.barplot(x="sepal_length", y="sepal_width", data=flower)
plt.show()

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load dataset
flower=sns.load_dataset("iris")
flower
# Draw a bar plot 
sns.barplot(x="sepal_length", y="sepal_width", data=flower)
# Adding titles
plt.title("DATASET OF IRIS PLOT")
plt.show()

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load dataset
flower=sns.load_dataset("iris")
flower
# Draw a bar plot 
sns.barplot(x="sepal_length", y="sepal_width", data=flower)
# Adding titles
plt.title("DATASET OF IRIS PLOT")
# Adding limits
plt.xlim(2)
plt.ylim(1)
plt.show()

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load dataset
flower=sns.load_dataset("iris")
flower
# Draw a bar plot 
sns.barplot(x="sepal_length", y="sepal_width", data=flower)
# Adding titles
plt.title("DATASET OF IRIS PLOT")
# Adding limits
plt.xlim(2)
plt.ylim(1)
# Adding labels
plt.xlabel("plot on x-axis")
plt.ylabel("plot on y-axis")
plt.show()

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load dataset
flower=sns.load_dataset("iris")
flower
# Draw a bar plot 
sns.barplot(x="sepal_length", y="sepal_width", data=flower)
# Adding titles
plt.title("DATASET OF IRIS PLOT")
# Adding limits
plt.xlim(2)
plt.ylim(1)
# Adding labels
plt.xlabel("plot on x-axis")
plt.ylabel("plot on y-axis")
# Adding figures
plt.figure(2)
plt.show()

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load dataset
flower=sns.load_dataset("iris")
flower
# Draw a bar plot 
sns.barplot(x="sepal_length", y="sepal_width", data=flower)
# Adding titles
plt.title("DATASET OF IRIS PLOT")
# Adding limits
plt.xlim(2)
plt.ylim(1)
# Adding labels
plt.xlabel("plot on x-axis")
plt.ylabel("plot on y-axis")
# Adding figures
plt.figure(2)
# Adding set styles
sns.set_style("ticks")
plt.show()

# %% [markdown]
# # Boat Dataset

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
# Load Dataset
boat=sns.load_dataset("titanic")
boat
# Draw a bar plot 
sns.barplot(x="survived", y="age", hue="who", data=boat)
# Adding titles
plt.title("PLOT OF TITANIC DATASET")
plt.show()
