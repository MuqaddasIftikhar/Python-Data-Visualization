# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# Line plot with multifacets

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd 
dot=sns.load_dataset("dots")
dot
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd 
dot=sns.load_dataset("dots")
dot
# Defining a color palette
palette=sns.color_palette('rocket_r')
# ploting
sns.relplot(data=dot, x="time", y="firing_rate", hue="coherence", size="choice", col="align", kind="line", 
            size_order=["T1", "T2"], palette=palette, height=5, aspect=0.75, facet_kws=dict(sharex=False),)

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
sns.set_theme(style="ticks", palette="pastel")
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
sns.set_theme(style="ticks", palette="pastel")
tip=sns.load_dataset("tips")
tip
# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="day", y="total_bill", data=tip, hue="smoker", palette=["m", "g"])
sns.despine(offset=10, trim=True)

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np 
sns.set_theme(style="whitegrid")
tip=sns.load_dataset("tips")
tip
sns.violinplot(data=tip, x="day", y="total_bill", hue="smoker", split=True, inner="quart", linewidth=1, palette={"Yes":"b", "No":"0.85"})
sns.despine(left=True)

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
sns.set_theme(style="whitegrid")
diamonds=sns.load_dataset("diamonds")
f, ax=plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
clarity_ranking=["I1", "SI2", "SI1", "VS2", "VS1", "WS2", "WS1", "IF"]
sns.scatterplot(x="carat", y="price", hue="clarity", size="depth", palette="ch:r=-0.2, d=0.3_r", hue_order=clarity_ranking,
                sizes=(1, 8), linewidth=0, data=diamonds, ax=ax)
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load dataset
diamonds=sns.load_dataset("diamonds")
diamonds
# Out:
#        carat        cut color clarity  depth  table   price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...     ...   ...   ...   ...
# 13244   1.14      Ideal     E     SI2   62.4   57.0  5473.0  6.64  6.70  4.16
# 13245   1.20  Very Good     G     SI2   60.2   63.0  5474.0  6.81  6.84  4.11
# 13246   1.20    Premium     I     VS2   62.1   59.0  5474.0  6.77  6.72  4.19
# 13247   1.01       Fair     G     VS2   66.6   55.0  5475.0  6.27  6.22  4.16
# 13248   0.90  Very Good   NaN     NaN    NaN    NaN     NaN   NaN   NaN   NaN
#
# [13249 rows x 10 columns]

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load dataset
diamonds=sns.load_dataset("diamonds")
diamonds
# Draw a line plot 
sns.lineplot(x="carat", y="price", data=diamonds)
plt.show()

# %%
sns.barplot(x="carat", y="price", data=diamonds)
plt.show()

# %%
sns.boxplot(x="carat", y="price", data=diamonds)
plt.show()

# %%
sns.scatterplot(x="carat", y="price", data=diamonds)
plt.show()

# %%
sns.catplot(x="carat", y="price", data=diamonds, palette="color_palette")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12272\2577215056.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.catplot(x="carat", y="price", data=diamonds, palette="color_palette")
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\HP\anaconda3\lib\site-packages\seaborn\palettes.py:235, in color_palette(palette, n_colors, desat, as_cmap)
#     233 try:
#     234     # Perhaps a named matplotlib colormap?
# --> 235     palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     236 except (ValueError, KeyError):  # Error class changed in mpl36
#
# File c:\Users\HP\anaconda3\lib\site-packages\seaborn\palettes.py:406, in mpl_palette(name, n_colors, as_cmap)
#     405 else:
# --> 406     cmap = get_colormap(name)
#     408 if name in MPL_QUAL_PALS:
#
# ...
