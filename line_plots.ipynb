# %% [markdown]
# # Data Visualization

# %% [markdown]
# For Data Visualization, we use and Import two Libraries:
# 1. Seaborn
# 2. Matplotlib

# %% [markdown]
# # IRIS DATASET

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Load dataset

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load Dataset
flower=sns.load_dataset("iris")
flower
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 2. Describe the loaded Dataset

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load Dataset
flower=sns.load_dataset("iris")
flower.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# 3. Head

# %%
flower.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# 4. Tail

# %%
flower.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %% [markdown]
# 5. Plotting and show the Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
# Load Dataset
flower=sns.load_dataset("iris")
flower
flower=sns.lineplot(x="sepal_length", y="sepal_width", data=flower)
plt.show()

# %% [markdown]
# 6. Adding Tiltes

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load Dataset
flower=sns.load_dataset("iris")
flower
# Draw a line plot 
sns.lineplot(x="sepal_length", y="sepal_width", data=flower)
plt.title("FLOWERS PLOT")
plt.show()

# %% [markdown]
# 7. Adding Limits

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load Dataset
flower=sns.load_dataset("iris")
flower
# Draw a line plot
sns.lineplot(x="sepal_length", y="sepal_width", data=flower)
# Adding Titles
plt.title("FLOWERS PLOT")
#  Adding Limits
plt.xlim(2)
plt.ylim(1)
plt.show()

# %% [markdown]
# 8. Adding Labels

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load Dataset
flower=sns.load_dataset("iris")
flower
# Draw a line plot 
sns.lineplot(x="sepal_length", y="sepal_width", data=flower)
# Adding Titles
plt.title("FLOWERS PLOT")
# Adding Limits
plt.xlim(2)
plt.ylim(1)
# Adding labels
plt.xlabel("plot on x-axis")
plt.ylabel("plot on y-axis")
plt.show()

# %% [markdown]
# 9. change the figure

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load Dataset
flower=sns.load_dataset("iris")
flower
# Draw a line plot
sns.lineplot(x="sepal_length", y="sepal_width", data=flower)
# Adding titles
plt.title("FLOWER PLOT OF IRIS DATASET")
# Adding limits
plt.xlim(2)
plt.ylim(1)
# Adding labels
plt.xlabel("plot on x-axis")
plt.ylabel("plot on y-axis")
# Change figure
plt.figure()
plt.show()

# %% [markdown]
# 10. Adding set Styles

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load Dataset
flower=sns.load_dataset("iris")
flower
# Draw a line plot
sns.lineplot(x="sepal_length", y="sepal_width", data=flower)
# Adding titles
plt.title("FLOWER PLOT OF IRIS DATASET")
# Adding limits
plt.xlim(2)
plt.ylim(1)
# Adding labels
plt.xlabel("plot on x-axis")
plt.ylabel("plot on y-axis")
# Change figure
plt.figure()
# Adding set Styles
sns.set_style("darkgrid")
plt.show()

# %% [markdown]
# # BOAT DATASET

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load dataset
boat=sns.load_dataset("titanic")
boat
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# 1. Load the dataset of Titanic

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load dataset
boat=sns.load_dataset("titanic")
boat.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# 2. Head

# %%
boat.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# 3. Tail

# %%
boat.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %% [markdown]
# 4. Line plot and show the plotting

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load dataset
boat=sns.load_dataset("titanic")
boat
# Draw a line plot 
sns.lineplot(x="survived", y="age", hue="who", data=boat)
plt.show()

# %% [markdown]
# 5. Adding Titles

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load dataset
boat=sns.load_dataset("titanic")
boat
sns.lineplot(x="survived", y="age", data=boat, hue="who")
plt.show()

# %% [markdown]
# 6. Adding Limits

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load dataset
boat=sns.load_dataset("titanic")
boat
# Draw a line plot 
sns.lineplot(x="survived", y="age", hue="who", data=boat)
# Adding Titles
plt.title("LINE PLOT OF TITANIC DATASET")
plt.show()

# %% [markdown]
# 7. Adding Limits

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load dataset
boat=sns.load_dataset("titanic")
boat
# Draw a line plot 
sns.lineplot(x="survived", y="age", hue="who", data=boat)
# Adding Titles
plt.title("LINE PLOT OF TITANIC DATASET")
# Adding Limits
plt.xlim(5)
plt.ylim(4)
plt.show()

# %% [markdown]
# 8. Adding Labels

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load dataset
boat=sns.load_dataset("titanic")
boat
# Draw a line plot 
sns.lineplot(x="survived", y="age", hue="who", data=boat)
# Adding Titles
plt.title("LINE PLOT OF TITANIC DATASET")
# Adding Limits
plt.xlim(5)
plt.ylim(4)
# Adding Labels
plt.xlabel("plot on x-axis")
plt.ylabel("plot on y-axis")
plt.show()

# %% [markdown]
# 9. Adding Figures

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load dataset
boat=sns.load_dataset("titanic")
boat
# Draw a line plot 
sns.lineplot(x="survived", y="age", hue="who", data=boat)
# Adding Titles
plt.title("LINE PLOT OF TITANIC DATASET")
# Adding Limits
plt.xlim(5)
plt.ylim(4)
# Adding Labels
plt.xlabel("plot on x-axis")
plt.ylabel("plot on y-axis")
# Adding Figures
plt.figure()
plt.show()

# %% [markdown]
# 10. Adding Set Styles

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# Load dataset
boat=sns.load_dataset("titanic")
boat
# Draw a line plot 
sns.lineplot(x="survived", y="age", hue="who", data=boat)
# Adding Titles
plt.title("LINE PLOT OF TITANIC DATASET")
# Adding Limits

# Adding Labels
plt.xlabel("plot on x-axis")
plt.ylabel("plot on y-axis")
# Adding Figures
plt.figure()
# Adding set Styles
sns.set_style("ticks")
plt.show()
